# %%
import json
import requests
import datetime
import pandas as pd

headers = {
'Accept': '*/*',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'zh-CN,zh;q=0.8,zh-TW;q=0.7,zh-HK;q=0.5,en-US;q=0.3,en;q=0.2',
'Connection': 'keep-alive',
'cookie': 'ECOM_SESS=jpfh64squilhp9clngqueavu12; datadome=7NtMzz6XlnQt9Q25_JIIUAS6uMndCnI._s3YBUf9dLAm6ByLbgJeeFzcL~QU2J4G5jIWCLt45psgbHEGrGRIAeKDFi0QZOparcIpuQMbs6',
'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36'
}
r = requests.get('https://bck.hermes.com/product?urlParams=fh_view_size=36%26country=us%26fh_location=--/categories%253C%257Bwomenbagsbagsclutches%257D%26fh_start_index=36&locale=us_en&category=WOMENBAGSBAGSCLUTCHES&sort=pricedsc&pagesize=72', headers=headers)
print(r.status_code)

# %%
wbdata = r.text
data = json.loads(wbdata)
bags = data['products']['items']

# %%
bags[0]
# Out:
# {'sku': 'H075248CK89',
#  'title': 'Hermes 2002 - 26 bag',
#  'productCode': 'C031',
#  'assets': [{'url': '//assets.hermes.com/is/image/hermesproduct/075248CK89_front_1?a=a&size=3000,3000&extend=300,300,300,300&align=0,1'},
#   {'url': '//assets.hermes.com/is/image/hermesproduct/075248CK89_side_2?a=a&size=3000,3000&extend=300,300,300,300&align=0,1'},
#   {'url': '//assets.hermes.com/is/image/hermesproduct/075248CK89_back_3?a=a&size=3000,3000&extend=300,300,300,300&align=0,1'},
#   {'url': '//assets.hermes.com/is/image/hermesproduct/075248CK89_above_4?a=a&size=3000,3000&extend=300,300,300,300&align=0,1'},
#   {'url': '//assets.hermes.com/is/image/hermesproduct/075248CK89_worn_6?a=a&size=3000,3000&extend=0,0,0,0&align=0,1'}],
#  'moreColors': False,
#  'size': 'SANS_TAILLE',
#  'avgColor': 'black',
#  'departmentCode': 'C',
#  'familyCode': 'C03',
#  'divisionCode': '01',
#  'price': 10900,
#  'url': '/product/hermes-2002-26-bag-H075248CK89',
#  'slug': 'hermes-2002-26-bag',
# ...

# %%
print(datetime.date.today())
for n in bags:    
    title = n['title']
    price = n['price']
    link = n['url']
    color = n['avgColor']
    url = "https://www.hermes.com/us/en"+link
    print(title,'Color:',color,'Price:',price)
    print(url)

# %%
pd.json_normalize(bags)
# Out:
#                sku                                  title productCode  \
# 0      H075248CK89                   Hermes 2002 - 26 bag        C031
# 1      H075316CKAA                   Hermes 2002 - 20 bag        C031
# 2      H076126CK89                Mosaique au 24 - 21 bag        C031
# 3      H076126CK55                Mosaique au 24 - 21 bag        C031
# 4      H075244CKAN                         24/24 - 35 bag        C031
# ..             ...                                    ...         ...
# 67  H073650CKAA070          Sangle Cavale 25 mm bag strap        C063
# 68  H073649CCAD105          Sangle Cavale 25 mm bag strap        C063
# 69  H079101CKAM085  Sangle Wooly 50 mm bicolore bag strap        C063
# 70     H063913CKAA                        Fourbi 25 pouch        C061
# 71     H063912CKAA                        Fourbi 20 pouch        C061
#
#                                                assets  moreColors  \
# ...
